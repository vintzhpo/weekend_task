# %%
import pandas as pd
df = pd.read_csv("../data/B_customer_churn.csv")
print(df.shape)
df.head()
df.info()
df.describe(include="all")
# Out:
# (8080, 10)
# <class 'pandas.DataFrame'>
# RangeIndex: 8080 entries, 0 to 8079
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              8080 non-null   str
#  1   plan_type                8080 non-null   str
#  2   tenure_months            8080 non-null   int64
#  3   monthly_spend            7751 non-null   float64
#  4   monthly_usage_gb         7743 non-null   float64
#  5   call_minutes             8080 non-null   int64
#  6   message_count            8080 non-null   int64
#  7   days_since_last_payment  8080 non-null   int64
#  8   complaints_count         8080 non-null   int64
#  9   is_churned               8080 non-null   int64
# dtypes: float64(2), int64(6), str(2)
# memory usage: 631.4 KB
#        customer_id plan_type  tenure_months  monthly_spend  monthly_usage_gb  \
# count         8080      8080    8080.000000    7751.000000       7743.000000
# unique        8000        12            NaN            NaN               NaN
# top     CUS0001714     basic            NaN            NaN               NaN
# freq             3      3640            NaN            NaN               NaN
# mean           NaN       NaN      36.461510      55.526626          8.218196
# std            NaN       NaN      21.091323     271.210025          5.416033
# min            NaN       NaN     -12.000000      10.000000          0.000000
# 25%            NaN       NaN      18.000000      19.790000          4.025000
# 50%            NaN       NaN      37.000000      30.210000          8.000000
# 75%            NaN       NaN      55.000000      62.785000         11.970000
# max            NaN       NaN      72.000000   11538.000000         33.720000
#
#         call_minutes  message_count  days_since_last_payment  \
# count    8080.000000    8080.000000              8080.000000
# unique           NaN            NaN                      NaN
# top              NaN            NaN                      NaN
# freq             NaN            NaN                      NaN
# mean      504.264604     150.583292                25.689233
# std       291.921952      87.003917                18.621508
# min         0.000000       0.000000                 0.000000
# 25%       253.000000      75.000000                11.000000
# 50%       503.000000     151.000000                22.000000
# 75%       762.000000     225.000000                37.000000
# max      1000.000000     300.000000               111.000000
#
#         complaints_count   is_churned
# count        8080.000000  8080.000000
# unique               NaN          NaN
# top                  NaN          NaN
# freq                 NaN          NaN
# mean            1.326856     0.185767
# std             1.732793     0.388943
# min             0.000000     0.000000
# 25%             0.000000     0.000000
# 50%             1.000000     0.000000
# 75%             2.000000     0.000000
# max             8.000000     1.000000

# %%
df["plan_type"].value_counts(dropna=False)
# Out:
# plan_type
# basic        3640
# standard     2196
# premium      1429
# Basic         145
# BASIC         131
#  basic        122
#  standard      94
# Standard       76
# STANDARD       73
#  premium       62
# Premium        56
# PREMIUM        56
# Name: count, dtype: int64

# %%
df["is_churned"].value_counts(normalize=True) * 100
# Out:
# is_churned
# 0    81.423267
# 1    18.576733
# Name: proportion, dtype: float64
